# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: rich in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from keras>=3.5.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.0.6)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (8.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize pixel values
y_train, y_test = to_categorical(y_train), to_categorical(y_test)  # One-hot encode labels

# Create notebook sections with markdown for structure
notebook_content = """
# MNIST Deep Learning Model Examples

In this notebook, we explore different neural network architectures to classify the MNIST dataset of handwritten digits.

## Step 1: Load and Preprocess Data
We load the MNIST dataset from Keras and normalize it so that pixel values are between 0 and 1. We also one-hot encode the labels.

```python
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0  # Normalize pixel values
y_train, y_test = to_categorical(y_train), to_categorical(y_test)  # One-hot encode labels
"""
# Out:
# /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

model1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history1 = model1.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# /Users/michaelnguyen/Library/Python/3.9/lib/python/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 628us/step - accuracy: 0.8826 - loss: 0.4212 - val_accuracy: 0.9532 - val_loss: 0.1511
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 556us/step - accuracy: 0.9625 - loss: 0.1268 - val_accuracy: 0.9690 - val_loss: 0.0991
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step - accuracy: 0.9762 - loss: 0.0812 - val_accuracy: 0.9762 - val_loss: 0.0818
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 529us/step - accuracy: 0.9806 - loss: 0.0627 - val_accuracy: 0.9753 - val_loss: 0.0792
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 523us/step - accuracy: 0.9871 - loss: 0.0444 - val_accuracy: 0.9796 - val_loss: 0.0713

# %%
model2 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='sigmoid'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 901us/step - accuracy: 0.8645 - loss: 0.4755 - val_accuracy: 0.9617 - val_loss: 0.1237
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 915us/step - accuracy: 0.9692 - loss: 0.0995 - val_accuracy: 0.9704 - val_loss: 0.0963
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9801 - loss: 0.0643 - val_accuracy: 0.9740 - val_loss: 0.0812
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 921us/step - accuracy: 0.9866 - loss: 0.0428 - val_accuracy: 0.9780 - val_loss: 0.0709
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9897 - loss: 0.0321 - val_accuracy: 0.9790 - val_loss: 0.0756

# %%
from tensorflow.keras.layers import Dropout

model3 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='tanh'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history3 = model3.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8366 - loss: 0.5103 - val_accuracy: 0.9617 - val_loss: 0.1186
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9441 - loss: 0.1829 - val_accuracy: 0.9698 - val_loss: 0.0962
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9546 - loss: 0.1502 - val_accuracy: 0.9711 - val_loss: 0.0955
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9615 - loss: 0.1277 - val_accuracy: 0.9741 - val_loss: 0.0853
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9643 - loss: 0.1147 - val_accuracy: 0.9769 - val_loss: 0.0796

# %%
model4 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='tanh'),
    Dense(128, activation='sigmoid'),
    Dense(10, activation='softmax')
])

model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history4 = model4.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 873us/step - accuracy: 0.8709 - loss: 0.4712 - val_accuracy: 0.9595 - val_loss: 0.1357
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - accuracy: 0.9649 - loss: 0.1174 - val_accuracy: 0.9704 - val_loss: 0.0905
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.9781 - loss: 0.0716 - val_accuracy: 0.9732 - val_loss: 0.0824
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 874us/step - accuracy: 0.9851 - loss: 0.0502 - val_accuracy: 0.9773 - val_loss: 0.0759
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 821us/step - accuracy: 0.9894 - loss: 0.0343 - val_accuracy: 0.9760 - val_loss: 0.0784

# %%
import matplotlib.pyplot as plt

# Function to plot accuracy and loss for each model
def plot_metrics(histories, model_names):
    plt.figure(figsize=(12, 5))
    
    # Plot accuracy
    plt.subplot(1, 2, 1)
    for history, name in zip(histories, model_names):
        plt.plot(history.history['accuracy'], label=f'{name} - Train')
        plt.plot(history.history['val_accuracy'], linestyle="--", label=f'{name} - Validation')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Plot loss
    plt.subplot(1, 2, 2)
    for history, name in zip(histories, model_names):
        plt.plot(history.history['loss'], label=f'{name} - Train')
        plt.plot(history.history['val_loss'], linestyle="--", label=f'{name} - Validation')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# List of histories and names for each model
histories = [history1, history2, history3, history4]
model_names = ['Simple Model', 'Multi-Layer Model', 'Dropout Model', 'Activation Experiment Model']

# Plot the metrics
plot_metrics(histories, model_names)

# %%
predictions = model1.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step

# %%
predicted_classes = predictions.argmax(axis=1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select an image from the test set
index = 0  # Change this index to view different images
image = X_test[index]

# Make a prediction for the selected image
prediction = model1.predict(np.expand_dims(image, axis=0))
predicted_class = prediction.argmax()

# Plot the image with the prediction
plt.imshow(image, cmap='gray')
plt.title(f"Predicted Class: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# True labels from the test set
true_classes = y_test.argmax(axis=1)

# Calculate accuracy
accuracy = np.mean(predicted_classes == true_classes)
print(f"Test Set Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Set Accuracy: 97.96%
